# %%
money = True
if money:
    print("택시를 타고 가라")
else:
    print("걸어 가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# 들여쓰기(indentation)를 해야 한다 하지 않으면 오류가 난다.
# if조건문 뒤에는 무조건 :이 나와야한다.

# %% [markdown]
# if 조건문:
#     수행할_문장1
#     수행할_문장2
#     ...
# else:
#     수행할_문장A
#     수행할_문장B
#     ...

# %%
x = 3
y = 2
x != y
# Out:
# True

# %%
money = 2000
if money >= 3000:
     print("택시를 타고 가라")
else:
     print("걸어가라")
# Out:
# 걸어가라

# %%
money = 2000
card = True
if money >= 3000 or card:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
money = 2000
card = True
if money >= 3000 and card:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 걸어가라

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
1 not in [1, 2, 3]
# Out:
# False

# %%
'a' in ('a', 'b', 'c')
# Out:
# True

# %%
'j' not in 'python'
# Out:
# True

# %%
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# 즉, elif는 이전 조건문이 거짓일 때 수행된다. if, elif, else를 모두 사용할 때 기본 구조는 다음과 같다.
#
# if 조건문:
#     수행할_문장1
#     수행할_문장2
#     ...
# elif 조건문:
#     수행할_문장1
#     수행할_문장2
#     ...
# elif 조건문:
#     수행할_문장1
#     수행할_문장2
#     ...
# ...
# else:
#    수행할_문장1
#    수행할_문장2
#    ...
#
# 위에서 볼 수 있듯이 elif는 개수에 제한 없이 사용할 수 있다.

# %%
score = 100
if score >= 60:
    message = "success"
else:
    message = "failure"

print(message)
# Out:
# success

# %%
# Out:
# True
