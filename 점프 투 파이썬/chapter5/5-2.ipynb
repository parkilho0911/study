# %% [markdown]
# # 05-2 모듈

# %%
# mod1.py
def add(a, b):
    return a + b

def sub(a, b): 
    return a-b

# %% [markdown]
# 클래스나 변수 등을 포함한 모듈

# %%
mod2.py
PI = 3.141592

class Math: 
    def solv(self, r): 
        return PI * (r ** 2) 

def add(a, b): 
    return a+b
