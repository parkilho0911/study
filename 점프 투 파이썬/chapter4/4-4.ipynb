# %% [markdown]
# # 04-4 프로그램의 입출력

# %% [markdown]
# ### sys 모듈 사용하기

# %%
# sys1.py
import sys

args = sys.argv[1:]
for i in args:
    print(i)
# Out:
# --f=c:\Users\ilho\AppData\Roaming\jupyter\runtime\kernel-v310cf626dad32459749492a05462e154b86862924.json
