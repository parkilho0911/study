# %%
print("Hello World!")
# Out:
# Hello World!

# %%
A,B = input().split()
a = int(A)
b = int(B)
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 A,B = input().split()
#       2 a = int(A)
#       3 b = int(B)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
A,B = input().split()
a = int(A)
b = int(B)
print(a-b)
